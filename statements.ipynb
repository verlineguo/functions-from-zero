# %% [markdown]
# <a href="https://colab.research.google.com/github/verlineguo/functions-from-zero/blob/main/statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Learning Statement

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ##Variables

# %%
variable = 1

# %%
x = 1

# %%
y = 2

# %%
x + y
# Out:
# 3

# %% [markdown]
# ##Data Structures

# %%
my_list = [1,2,3]

# %%
my_list[0]
# Out:
# 1

# %%
my_list[1]
# Out:
# 2

# %%
my_list[2]
# Out:
# 3

# %%
type(my_list)
# Out:
# list

# %% [markdown]
# #### Dictionary

# %%
my_dict = {1:"one", 2:"two"}

# %%
type(my_dict)
# Out:
# dict

# %%
my_dict.keys()
# Out:
# dict_keys([1, 2])

# %%
my_dict.values()
# Out:
# dict_values(['one', 'two'])

# %%
for key,value in my_dict.items():
  print(f"This is my key: {key}")
  print(f"This is my value: {value}")
# Out:
# This is my key: 1
# This is my value: one
# This is my key: 2
# This is my value: two

# %%
for item in my_list:
  print(f"This is the value of the list: {item}")
# Out:
# This is the value of the list: 1
# This is the value of the list: 2
# This is the value of the list: 3

# %%
print
